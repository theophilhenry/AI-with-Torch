# %%
from ultralytics import YOLO
import cv2

model = YOLO('yolo11n.pt')
img = cv2.imread('data/street.jpg')

# results = model.predict(img, show=True)
result = model(img)

for result in results:
  boxes = result.boxes
  print(boxes.cls)
  for box in boxes:
    x1, y1, x2, y2 = box.xyxy[0].int().tolist()
    conf = box.conf[0].item()
    cls = int(box.cls[0])
    label = model.names[cls]
    
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 0, 255), 2)
    cv2.putText(img, f"{label} {conf:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

cv2.imwrite('output.jpg', img)
print("✅ Detection complete. Saved as output.jpg")
# Out:
# 0: 416x640 11 persons, 1 stop sign, 1 handbag, 4 chairs, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# tensor([ 0.,  0.,  0.,  0.,  0., 11.,  0.,  0., 56., 56., 56.,  0., 26.,  0., 56.,  0.,  0.])
# ✅ Detection complete. Saved as output.jpg

# %%
def count_up_to(max_num):
    n = 0
    while n <= max_num:
        yield n  # Pause and return 'n'
        n += 1

# Create a generator object
counter = count_up_to(5)

# Get values one by one
print(next(counter)) # Output: 0
print(next(counter)) # Output: 1

# Iterate through the rest
for num in counter:
    print(num) # Output: 2, 3, 4, 5
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
